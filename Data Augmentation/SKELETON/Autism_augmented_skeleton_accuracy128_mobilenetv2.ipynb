# %% [markdown]
# ### Author: Vaishnav Krishna P
# - vyshnavkrishnap2020@gmail.com

# %% [markdown]
# ### 1.Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. **Import** Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, matthews_corrcoef
import seaborn as sns

# %% [markdown]
# ### 3. Define Dataset Path

# %%
data_dir = "/content/drive/MyDrive/TransformedImages"
IMG_SIZE = 128
BATCH_SIZE = 16

# %% [markdown]
# ### 4. Load Dataset

# %%
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="binary"
)
# Out:
# Found 2564 files belonging to 2 classes.
# Using 2052 files for training.
# Found 2564 files belonging to 2 classes.
# Using 512 files for validation.

# %% [markdown]
# ### 5. Preprocessing

# %%
train_dataset = train_dataset.map(lambda x, y: (preprocess_input(x), y))
val_dataset = val_dataset.map(lambda x, y: (preprocess_input(x), y))

# %% [markdown]
# ### 6.Load MobileNetV2 Base

# %%
base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Freeze base
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ### 7. Build Final Model

# %%
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# ### 8. Compile Model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# ### 9. Early Stopping

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

# %% [markdown]
# ### 10. Train Model

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=20,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 325s 2s/step - accuracy: 0.5883 - loss: 0.7982 - val_accuracy: 0.7520 - val_loss: 0.4970
# Epoch 2/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.7111 - loss: 0.5653 - val_accuracy: 0.7480 - val_loss: 0.4864
# Epoch 3/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.7383 - loss: 0.5219 - val_accuracy: 0.7617 - val_loss: 0.4789
# Epoch 4/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.7611 - loss: 0.5067 - val_accuracy: 0.7637 - val_loss: 0.4716
# Epoch 5/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.7595 - loss: 0.4898 - val_accuracy: 0.7812 - val_loss: 0.4647
# Epoch 6/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.7759 - loss: 0.4738 - val_accuracy: 0.7754 - val_loss: 0.4606
# Epoch 7/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 69ms/step - accuracy: 0.7776 - loss: 0.4671 - val_accuracy: 0.7793 - val_loss: 0.4547
# Epoch 8/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.7751 - loss: 0.4605 - val_accuracy: 0.7773 - val_loss: 0.4500
# Epoch 9/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.8082 - loss: 0.4335 - val_accuracy: 0.7812 - val_loss: 0.4532
# Epoch 10/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.8081 - loss: 0.4397 - val_accuracy: 0.7812 - val_loss: 0.4457
# Epoch 11/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.7912 - loss: 0.4235 - val_accuracy: 0.7832 - val_loss: 0.4428
# Epoch 12/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - accuracy: 0.8183 - loss: 0.4026 - val_accuracy: 0.7891 - val_loss: 0.4376
# Epoch 13/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.8200 - loss: 0.4025 - val_accuracy: 0.7852 - val_loss: 0.4375
# Epoch 14/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.8092 - loss: 0.4032 - val_accuracy: 0.7891 - val_loss: 0.4301
# Epoch 15/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.8159 - loss: 0.3832 - val_accuracy: 0.7891 - val_loss: 0.4286
# Epoch 16/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.8313 - loss: 0.3887 - val_accuracy: 0.7910 - val_loss: 0.4373
# Epoch 17/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.8307 - loss: 0.3708 - val_accuracy: 0.7891 - val_loss: 0.4242
# Epoch 18/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.8339 - loss: 0.3582 - val_accuracy: 0.7891 - val_loss: 0.4224
# Epoch 19/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.8397 - loss: 0.3624 - val_accuracy: 0.7930 - val_loss: 0.4193
# Epoch 20/20
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - accuracy: 0.8372 - loss: 0.3549 - val_accuracy: 0.7949 - val_loss: 0.4153

# %% [markdown]
# ### TEST EVALUATION METRICS

# %%
y_true = []
y_pred = []

for images, labels in val_dataset:
    preds = model.predict(images)
    preds = (preds > 0.5).astype(int)
    y_true.extend(labels.numpy())
    y_pred.extend(preds.flatten())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
mcc = matthews_corrcoef(y_true, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall (Sensitivity):", recall)
print("F1 Score:", f1)
print("MCC:", mcc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Accuracy: 0.794921875
# Precision: 0.7675675675675676
# Recall (Sensitivity): 0.696078431372549
# F1 Score: 0.7300771208226221
# MCC: 0.5671147318988092

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=["No ASD", "ASD"],
            yticklabels=["No ASD", "ASD"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
epochs_range = range(1, len(history.history['accuracy']) + 1)

# Accuracy
plt.figure(figsize=(8,5))
plt.plot(epochs_range, history.history['accuracy'], marker='o', linestyle='-')
plt.plot(epochs_range, history.history['val_accuracy'], marker='s', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy (MobileNetV2)')
plt.xticks(epochs_range)
plt.grid(True)
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

# %%
# Loss
plt.figure(figsize=(8,5))
plt.plot(epochs_range, history.history['loss'], marker='o', linestyle='-')
plt.plot(epochs_range, history.history['val_loss'], marker='s', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss (MobileNetV2)')
plt.xticks(epochs_range)
plt.grid(True)
plt.legend(['Training Loss','Validation Loss'])
plt.show()
