# %% [markdown]
# ### Author: Vaishnav Krishna P
# - vyshnavkrishnap2020@gmail.com

# %% [markdown]
# ### 1.Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. **Import** Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, matthews_corrcoef
import seaborn as sns

# %% [markdown]
# ### 3. Define Dataset Path

# %%
data_dir = "/content/drive/MyDrive/TransformedImages_NoSkeleton"
IMG_SIZE = 224
BATCH_SIZE = 16

# %% [markdown]
# ### 4. Load Dataset

# %%
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="binary"
)
# Out:
# Found 547 files belonging to 2 classes.
# Using 438 files for training.
# Found 547 files belonging to 2 classes.
# Using 109 files for validation.

# %% [markdown]
# ### 5. Preprocessing

# %%
train_dataset = train_dataset.map(lambda x, y: (preprocess_input(x), y))
val_dataset = val_dataset.map(lambda x, y: (preprocess_input(x), y))

# %% [markdown]
# ### 6.Load MobileNetV2 Base

# %%
base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False   # Freeze base
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ### 7. Build Final Model

# %%
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# ### 8. Compile Model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# ### 9. Early Stopping

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

# %% [markdown]
# ### 10. Train Model

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=20,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.4941 - loss: 0.8673 - val_accuracy: 0.6147 - val_loss: 0.6379
# Epoch 2/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 715ms/step - accuracy: 0.6274 - loss: 0.6367 - val_accuracy: 0.6697 - val_loss: 0.5978
# Epoch 3/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 678ms/step - accuracy: 0.6500 - loss: 0.6598 - val_accuracy: 0.6972 - val_loss: 0.5801
# Epoch 4/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 743ms/step - accuracy: 0.6726 - loss: 0.6209 - val_accuracy: 0.7523 - val_loss: 0.5716
# Epoch 5/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 740ms/step - accuracy: 0.7315 - loss: 0.5730 - val_accuracy: 0.7339 - val_loss: 0.5601
# Epoch 6/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 719ms/step - accuracy: 0.6675 - loss: 0.5910 - val_accuracy: 0.7431 - val_loss: 0.5555
# Epoch 7/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 661ms/step - accuracy: 0.6945 - loss: 0.5805 - val_accuracy: 0.7431 - val_loss: 0.5545
# Epoch 8/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 681ms/step - accuracy: 0.7367 - loss: 0.5684 - val_accuracy: 0.7523 - val_loss: 0.5382
# Epoch 9/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 743ms/step - accuracy: 0.7245 - loss: 0.5812 - val_accuracy: 0.7615 - val_loss: 0.5415
# Epoch 10/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 657ms/step - accuracy: 0.7480 - loss: 0.5445 - val_accuracy: 0.7248 - val_loss: 0.5387
# Epoch 11/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 741ms/step - accuracy: 0.7027 - loss: 0.5650 - val_accuracy: 0.7523 - val_loss: 0.5371
# Epoch 12/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 666ms/step - accuracy: 0.7481 - loss: 0.5284 - val_accuracy: 0.7615 - val_loss: 0.5321
# Epoch 13/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 686ms/step - accuracy: 0.7382 - loss: 0.5415 - val_accuracy: 0.7248 - val_loss: 0.5344
# Epoch 14/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 736ms/step - accuracy: 0.7128 - loss: 0.5437 - val_accuracy: 0.7523 - val_loss: 0.5288
# Epoch 15/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 41s 737ms/step - accuracy: 0.7639 - loss: 0.5101 - val_accuracy: 0.7431 - val_loss: 0.5289
# Epoch 16/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 670ms/step - accuracy: 0.7510 - loss: 0.5203 - val_accuracy: 0.7339 - val_loss: 0.5293
# Epoch 17/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 730ms/step - accuracy: 0.7336 - loss: 0.5370 - val_accuracy: 0.7431 - val_loss: 0.5291

# %% [markdown]
# ### TEST EVALUATION METRICS

# %%
y_true = []
y_pred = []

for images, labels in val_dataset:
    preds = model.predict(images)
    preds = (preds > 0.5).astype(int)
    y_true.extend(labels.numpy())
    y_pred.extend(preds.flatten())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
mcc = matthews_corrcoef(y_true, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall (Sensitivity):", recall)
print("F1 Score:", f1)
print("MCC:", mcc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 889ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 869ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 778ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Accuracy: 0.7522935779816514
# Precision: 0.7857142857142857
# Recall (Sensitivity): 0.5116279069767442
# F1 Score: 0.6197183098591549
# MCC: 0.47062674747938393

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=["No ASD", "ASD"],
            yticklabels=["No ASD", "ASD"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
epochs_range = range(1, len(history.history['accuracy']) + 1)

# Accuracy
plt.figure(figsize=(8,5))
plt.plot(epochs_range, history.history['accuracy'], marker='o', linestyle='-')
plt.plot(epochs_range, history.history['val_accuracy'], marker='s', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy (MobileNetV2)')
plt.xticks(epochs_range)
plt.grid(True)
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

# %%
# Loss
plt.figure(figsize=(8,5))
plt.plot(epochs_range, history.history['loss'], marker='o', linestyle='-')
plt.plot(epochs_range, history.history['val_loss'], marker='s', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss (MobileNetV2)')
plt.xticks(epochs_range)
plt.grid(True)
plt.legend(['Training Loss','Validation Loss'])
plt.show()
