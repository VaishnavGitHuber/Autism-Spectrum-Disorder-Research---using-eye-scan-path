# %% [markdown]
# ### Author: Vaishnav Krishna P
# - vyshnavkrishnap2020@gamil.com

# %% [markdown]
# ### 1. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 2. Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, matthews_corrcoef
import seaborn as sns

# %% [markdown]
# ### 3. Dataset Path and Parameters

# %%
data_dir = "/content/drive/MyDrive/TransformedImages"
IMG_SIZE = 224
BATCH_SIZE = 16

# %% [markdown]
# ### 4. Load Dataset

# %%
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="binary"
)

val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    label_mode="binary"
)
# Out:
# Found 547 files belonging to 2 classes.
# Using 438 files for training.
# Found 547 files belonging to 2 classes.
# Using 109 files for validation.

# %% [markdown]
# ### 5. Preprocessing

# %%
train_dataset = train_dataset.map(lambda x, y: (preprocess_input(x), y))
val_dataset = val_dataset.map(lambda x, y: (preprocess_input(x), y))

# %% [markdown]
# ### 6. Load DenseNet121 Base Model

# %%
base_model = DenseNet121(
    weights="imagenet",
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)

base_model.trainable = False  # Freeze base
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %% [markdown]
# ### 7. Build Final Model

# %%
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
])

# %% [markdown]
# ### 8. Compile Model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# ### 9. Early Stopping

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

# %% [markdown]
# ### 10. Train Model

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=20,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 141s 4s/step - accuracy: 0.5466 - loss: 0.7781 - val_accuracy: 0.5780 - val_loss: 0.6764
# Epoch 2/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.5502 - loss: 0.7146 - val_accuracy: 0.6789 - val_loss: 0.6445
# Epoch 3/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.5722 - loss: 0.6911 - val_accuracy: 0.6789 - val_loss: 0.6200
# Epoch 4/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.5890 - loss: 0.6828 - val_accuracy: 0.7156 - val_loss: 0.6044
# Epoch 5/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.6445 - loss: 0.6315 - val_accuracy: 0.7156 - val_loss: 0.5919
# Epoch 6/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.6641 - loss: 0.6313 - val_accuracy: 0.7156 - val_loss: 0.5825
# Epoch 7/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.6826 - loss: 0.6370 - val_accuracy: 0.7431 - val_loss: 0.5776
# Epoch 8/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.6587 - loss: 0.6240 - val_accuracy: 0.7523 - val_loss: 0.5712
# Epoch 9/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.7013 - loss: 0.6065 - val_accuracy: 0.7339 - val_loss: 0.5679
# Epoch 10/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.6728 - loss: 0.6164 - val_accuracy: 0.7339 - val_loss: 0.5622
# Epoch 11/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.7273 - loss: 0.5825 - val_accuracy: 0.7706 - val_loss: 0.5596
# Epoch 12/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.7040 - loss: 0.5911 - val_accuracy: 0.7615 - val_loss: 0.5578
# Epoch 13/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.7255 - loss: 0.5757 - val_accuracy: 0.7523 - val_loss: 0.5557
# Epoch 14/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.6890 - loss: 0.5641 - val_accuracy: 0.7706 - val_loss: 0.5535
# Epoch 15/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.7185 - loss: 0.5673 - val_accuracy: 0.7890 - val_loss: 0.5524
# Epoch 16/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6856 - loss: 0.5635 - val_accuracy: 0.7615 - val_loss: 0.5496
# Epoch 17/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 82ms/step - accuracy: 0.7111 - loss: 0.5730 - val_accuracy: 0.7890 - val_loss: 0.5482
# Epoch 18/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.6600 - loss: 0.5835 - val_accuracy: 0.7890 - val_loss: 0.5462
# Epoch 19/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.6973 - loss: 0.5916 - val_accuracy: 0.7890 - val_loss: 0.5426
# Epoch 20/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.7281 - loss: 0.5572 - val_accuracy: 0.7706 - val_loss: 0.5393

# %% [markdown]
# ### TEST EVALUATION METRICS

# %%
y_true = []
y_pred = []

for images, labels in val_dataset:
    preds = model.predict(images)
    preds = (preds > 0.5).astype(int)
    y_true.extend(labels.numpy())
    y_pred.extend(preds.flatten())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)   # Sensitivity
f1 = f1_score(y_true, y_pred)
mcc = matthews_corrcoef(y_true, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall (Sensitivity):", recall)
print("F1 Score:", f1)
print("MCC:", mcc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# Accuracy: 0.7706422018348624
# Precision: 0.875
# Recall (Sensitivity): 0.4883720930232558
# F1 Score: 0.6268656716417911
# MCC: 0.5224130274241683

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=["No ASD", "ASD"],
            yticklabels=["No ASD", "ASD"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
epochs_range = range(1, len(history.history['accuracy']) + 1)

# Accuracy
plt.figure(figsize=(8,5))
plt.plot(epochs_range, history.history['accuracy'], marker='o', linestyle='-')
plt.plot(epochs_range, history.history['val_accuracy'], marker='s', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training & Validation Accuracy (DenseNet121)')
plt.xticks(epochs_range)
plt.grid(True)
plt.legend(['Training Accuracy','Validation Accuracy'])
plt.show()

# %%
# Loss
plt.figure(figsize=(8,5))
plt.plot(epochs_range, history.history['loss'], marker='o', linestyle='-')
plt.plot(epochs_range, history.history['val_loss'], marker='s', linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training & Validation Loss (DenseNet121)')
plt.xticks(epochs_range)
plt.grid(True)
plt.legend(['Training Loss','Validation Loss'])
plt.show()
